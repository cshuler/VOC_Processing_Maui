# %% [markdown]
# # VOC Processing Data

# %% [markdown]
# ## Code for processing availible data on Github

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import StringIO

# %% [markdown]
# ### Sample Metadata

# %%
# ----------------------------------------------------------------------------------------------------#
# - Bring in public data -
# ----------------------------------------------------------------------------------------------------#

# Try and access file path of public data 
url = 'https://github.com/cshuler/VOC_Processing_Maui/blob/main/MASTER_Maui_VOC_Sheet_PUBLIC.csv?raw=true'
df = pd.read_csv(url,index_col=0)
print(df.head(5))
#Only have tapwater samples 
tap_water_variations = ['Tap Water', 'tap', 'Tap', 'tap water']
#Filter the dataframe
tapwaterdf = df[df['SampleType'].isin(tap_water_variations)]
tapwaterdf
# Out:
#      Sample ID          SampleType   DateTime Taken Post Results    Public X  \
# 0  08-16-CKS-1           DI water    8/16/2023 8:15            N -156.475003
# 1  08-16-CKS-2           Tap Water   8/16/2023 9:30          NaN -156.311886
# 2  08-16-CKS-3           Tap Water  8/16/2023 10:52          NaN -156.309926
# 3  08-16-CKS-4           Tap Water  8/16/2023 11:11          NaN -156.307487
# 4  08-16-CKS-5  Tap Water Filtered  8/16/2023 11:30          NaN -156.308135
#
#     Public Y
# 0  20.891460
# 1  20.778782
# 2  20.779907
# 3  20.775916
# 4  20.778905
#            Sample ID SampleType   DateTime Taken Post Results    Public X  \
# 1        08-16-CKS-2  Tap Water   8/16/2023 9:30          NaN -156.311886
# 2        08-16-CKS-3  Tap Water  8/16/2023 10:52          NaN -156.309926
# 3        08-16-CKS-4  Tap Water  8/16/2023 11:11          NaN -156.307487
# 5        08-16-CKS-6  Tap Water  8/16/2023 12:00          NaN -156.310399
# 6        08-16-CKS-7  Tap Water  8/16/2023 12:22          NaN -156.309802
# ..               ...        ...              ...          ...         ...
# 647  10-04-24-KDP-02  Tap Water  10/4/2024 14:46          NaN -156.314311
# 649  10-04-24-KDP-04  Tap Water  10/4/2024 14:52          NaN -156.321881
# 651  10-04-24-KDP-06  Tap Water  10/4/2024 15:10          NaN -156.214123
# 652  10-04-24-KDP-07  Tap Water  10/4/2024 15:13          NaN -156.379997
# 654  10-04-24-KDP-09  Tap Water  10/4/2024 15:21          NaN -156.496896
#
#       Public Y
# 1    20.778782
# 2    20.779907
# 3    20.775916
# 5    20.774751
# 6    20.773082
# ..         ...
# 647  20.877163
# 649  20.918979
# 651  20.895677
# 652  20.915937
# 654  20.923693
#
# [382 rows x 6 columns]

# %% [markdown]
# ### VOC data

# %%
# ----------------------------------------------------------------------------------------------------#
# - Bring in clean VOC data -
# ----------------------------------------------------------------------------------------------------#

#Function to get the list of CSV files from the GitHub repository page
def get_csv_files_from_repo(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        files = response.json()
        csv_files = [file['download_url'] for file in files if file['name'].endswith('.csv')]
        return csv_files
    else:
        raise ValueError(f"Failed to fetch repository contents: {response.status_code}")

#URL of the GitHub repository API
api_url = "https://api.github.com/repos/cshuler/VOC_Processing_Maui/contents/Clean_Data"

# Get the list of CSV files
csv_files = get_csv_files_from_repo(api_url)
csv_files
# Check if the list of CSV files is populated
if not csv_files:
    raise ValueError("No CSV files found in the repository")

# Function to read a CSV file from a URL into a DataFrame
def read_csv_from_url(url):
    response = requests.get(url)
    response.raise_for_status()  # Raise an error for bad status codes
    return pd.read_csv(StringIO(response.text))

# Read all CSV files into a list of DataFrames and set 'Peak' as the index
dataframes = []
for url in csv_files:
    try:
        df = read_csv_from_url(url)
        df.set_index('Peak', inplace=True)
        dataframes.append(df)
    except Exception as e:
        print(f"Error reading {url}: {e}")
# Ensure there are DataFrames to concatenate
if not dataframes:
    raise ValueError("No DataFrames were read successfully")
dataframes
# Out:
# Error reading https://raw.githubusercontent.com/cshuler/VOC_Processing_Maui/main/Clean_Data/tapwaterresults_clean.csv: "None of ['Peak'] are in the columns"
# [                                 Reporting_Limit HolmesTap 08-16-CKS-1  \
#  Peak
#  Chloromethane (methyl chloride)              2.0      n.a.        n.a.
#  Chloroethene (vinyl chloride)                2.0       NaN         NaN
#  Bromomethane (methyl bromide)                2.0     0.138       0.182
#  Chloroethane (ethyl chloride)                2.0      n.a.       0.039
#  Trichlorofluoromethane                       2.0     0.007       0.001
#  ...                                          ...       ...         ...
#  Nitrobenzene                                 2.0      n.a.        n.a.
#  1,2,4-Trichlorobenzene                       2.0     0.269       0.011
#  Hexachloro-1,3-butadiene                     2.0     0.188       0.004
#  Naphthalene                                  2.0     0.249       0.012
#  1,2,3-Trichlorobenzene                       2.0     0.388        n.a.
#
#                                  08-16-CKS-2 08-16-CKS-7 08-16-CKS-8  \
#  Peak
#  Chloromethane (methyl chloride)        n.a.        n.a.        n.a.
#  Chloroethene (vinyl chloride)           NaN         NaN         NaN
#  Bromomethane (methyl bromide)         0.182        n.a.       0.244
#  Chloroethane (ethyl chloride)          n.a.       0.041        n.a.
#  Trichlorofluoromethane                 n.a.        n.a.        n.a.
#  ...                                     ...         ...         ...
#  Nitrobenzene                           n.a.        n.a.        n.a.
#  1,2,4-Trichlorobenzene                0.025       0.072       0.018
#  Hexachloro-1,3-butadiene              0.008       0.046       0.006
#  Naphthalene                            0.02       0.054       0.021
#  1,2,3-Trichlorobenzene                0.025       0.082       0.022
#
#                                  08-16-CKS-10 08-16-CKS-12
#  Peak
#  Chloromethane (methyl chloride)         n.a.         n.a.
#  Chloroethene (vinyl chloride)            NaN          NaN
#  Bromomethane (methyl bromide)          0.248        0.234
#  Chloroethane (ethyl chloride)          0.156         n.a.
#  Trichlorofluoromethane                  n.a.         n.a.
#  ...                                      ...          ...
#  Nitrobenzene                            n.a.         n.a.
#  1,2,4-Trichlorobenzene                 0.013        0.041
#  Hexachloro-1,3-butadiene               0.005        0.023
#  Naphthalene                            0.032        0.093
#  1,2,3-Trichlorobenzene                  n.a.        0.049
#
#  [88 rows x 8 columns],
#                                   Reporting_Limit DIH2O-Vial Fridge-Blank  \
#  Peak
#  Chloromethane (methyl chloride)              2.0       n.a.         n.a.
#  Chloroethene (vinyl chloride)                2.0        NaN          NaN
#  Bromomethane (methyl bromide)                2.0      0.316        0.332
#  Chloroethane (ethyl chloride)                2.0       n.a.         n.a.
#  Trichlorofluoromethane                       2.0      0.008        0.003
#  ...                                          ...        ...          ...
#  Nitrobenzene                                 2.0       n.a.         n.a.
#  1,2,4-Trichlorobenzene                       2.0      0.287        0.091
#  Hexachloro-1,3-butadiene                     2.0      0.183        0.059
#  Naphthalene                                  2.0      0.263        0.074
#  1,2,3-Trichlorobenzene                       2.0      0.405        0.109
#
#                                  08-16-CKS-3 08-16-CKS-4 08-16-CKS-5  \
#  Peak
#  Chloromethane (methyl chloride)        n.a.        n.a.        n.a.
#  Chloroethene (vinyl chloride)           NaN         NaN         NaN
#  Bromomethane (methyl bromide)         0.347       0.386       0.381
#  Chloroethane (ethyl chloride)          0.04        n.a.        n.a.
#  Trichlorofluoromethane                 n.a.        n.a.        n.a.
#  ...                                     ...         ...         ...
#  Nitrobenzene                           n.a.        n.a.        n.a.
#  1,2,4-Trichlorobenzene                 0.02       0.037       0.032
#  Hexachloro-1,3-butadiene              0.009       0.017       0.016
#  Naphthalene                           0.017       0.031       0.022
#  1,2,3-Trichlorobenzene                0.019       0.045       0.036
#
#                                  08-16-CKS-6 08-16-CKS-11
#  Peak
#  Chloromethane (methyl chloride)       0.334         n.a.
#  Chloroethene (vinyl chloride)           NaN          NaN
#  Bromomethane (methyl bromide)         0.361        0.403
#  Chloroethane (ethyl chloride)          n.a.         n.a.
#  Trichlorofluoromethane                 n.a.         n.a.
#  ...                                     ...          ...
#  Nitrobenzene                           n.a.         n.a.
#  1,2,4-Trichlorobenzene                0.057         0.03
#  Hexachloro-1,3-butadiene              0.025        0.014
#  Naphthalene                           0.039        0.047
#  1,2,3-Trichlorobenzene                0.063        0.038
#
#  [88 rows x 8 columns],
#                                  Reporting_Limit 08-23-CKS-21A 08-23-CKS-21B  \
#  Peak
#  Chloromethane (methyl chloride)               1     n.a./n.r.        0.0774
#  Chloroethene (vinyl chloride)                 1     n.a./n.r.     n.a./n.r.
#  Bromomethane (methyl bromide)                 1     n.a./n.r.        0.0802
#  Chloroethane (ethyl chloride)                 1     n.a./n.r.     n.a./n.r.
#  Trichlorofluoromethane                        1     n.a./n.r.     n.a./n.r.
#  ...                                         ...           ...           ...
#  Nitrobenzene                                  1     n.a./n.r.     n.a./n.r.
#  1,2,4-Trichlorobenzene                        1        0.1201        0.1452
#  Hexachloro-1,3-butadiene                      1         0.107        0.0967
#  Naphthalene                                   1        0.0725        0.1095
#  1,2,3-Trichlorobenzene                        1         0.114        0.1216
#
#                                  08-23-CKS-22 08-23-CKS-23 Holmes Tap  \
#  Peak
#  Chloromethane (methyl chloride)       0.0921       0.0822  n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)         0.1029       0.0849     0.0871
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.  n.a./n.r.
#  ...                                      ...          ...        ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene                0.0883        0.053      0.043
#  Hexachloro-1,3-butadiene              0.0477       0.0333  n.a./n.r.
#  Naphthalene                           0.0504       0.0911      0.033
#  1,2,3-Trichlorobenzene                0.0782    n.a./n.r.  n.a./n.r.
#
#                                  08-23-CKS-Chris Blank 08-25-CKS-34  \
#  Peak
#  Chloromethane (methyl chloride)                0.0738    n.a./n.r.
#  Chloroethene (vinyl chloride)               n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)                  0.0619       0.0701
#  Chloroethane (ethyl chloride)               n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane                      n.a./n.r.    n.a./n.r.
#  ...                                               ...          ...
#  Nitrobenzene                                n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene                         0.0442       0.0427
#  Hexachloro-1,3-butadiene                    n.a./n.r.       0.0222
#  Naphthalene                                    0.0283        0.028
#  1,2,3-Trichlorobenzene                         0.0355    n.a./n.r.
#
#                                  08-25-CKS-33 08-25-CKS-32 08-25-CKS-35  \
#  Peak
#  Chloromethane (methyl chloride)       0.0669       0.0946       0.0744
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)         0.0644       0.0914       0.0762
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene             n.a./n.r.        0.037    n.a./n.r.
#  Hexachloro-1,3-butadiene           n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Naphthalene                           0.0213    n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene             n.a./n.r.    n.a./n.r.    n.a./n.r.
#
#                                  09-01-CKS-61 09-01-CKS-62
#  Peak
#  Chloromethane (methyl chloride)       0.0751        0.067
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)         0.0704       0.0806
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene             n.a./n.r.    n.a./n.r.
#  Hexachloro-1,3-butadiene           n.a./n.r.    n.a./n.r.
#  Naphthalene                        n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene             n.a./n.r.    n.a./n.r.
#
#  [85 rows x 13 columns],
#                                  Reporting_Limit        B-1        A-1  \
#  Peak
#  Chloromethane (methyl chloride)               1  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)                 1  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)                 1     0.0655     0.0656
#  Chloroethane (ethyl chloride)                 1  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                        1  n.a./n.r.  n.a./n.r.
#  ...                                         ...        ...        ...
#  Nitrobenzene                                  1  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene                        1  n.a./n.r.  n.a./n.r.
#  Hexachloro-1,3-butadiene                      1     0.0267  n.a./n.r.
#  Naphthalene                                   1     0.0356  n.a./n.r.
#  1,2,3-Trichlorobenzene                        1  n.a./n.r.  n.a./n.r.
#
#                                         C-1        D-1      E-1-A        F-1  \
#  Peak
#  Chloromethane (methyl chloride)      0.084     0.0936     0.1121     0.0868
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)       0.0819     0.0891     0.0871     0.0823
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  ...                                    ...        ...        ...        ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene           n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Hexachloro-1,3-butadiene         n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Naphthalene                      n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#
#                                         G-1         31
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.     0.0632
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)       0.0725  n.a./n.r.
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.
#  ...                                    ...        ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene           n.a./n.r.  n.a./n.r.
#  Hexachloro-1,3-butadiene         n.a./n.r.  n.a./n.r.
#  Naphthalene                      n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.  n.a./n.r.
#
#  [85 rows x 9 columns],
#                                  Reporting_Limit        Z-1        W-1  \
#  Peak
#  Chloromethane (methyl chloride)               2  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)                 2  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)                 2     0.0911     0.0964
#  Chloroethane (ethyl chloride)                 2  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                        2  n.a./n.r.  n.a./n.r.
#  ...                                         ...        ...        ...
#  Nitrobenzene                                  2  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene                        2  n.a./n.r.  n.a./n.r.
#  Hexachloro-1,3-butadiene                      2  n.a./n.r.  n.a./n.r.
#  Naphthalene                                   2  n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene                        2  n.a./n.r.  n.a./n.r.
#
#                                         X-1
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.
#  Chloroethane (ethyl chloride)    n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.
#  ...                                    ...
#  Nitrobenzene                     n.a./n.r.
#  1,2,4-Trichlorobenzene           n.a./n.r.
#  Hexachloro-1,3-butadiene         n.a./n.r.
#  Naphthalene                      n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.
#
#  [85 rows x 4 columns],
#                                   Reporting_Limit     Fridge 08-29-CKS-41  \
#  Peak
#  Chloromethane (methyl chloride)              2.0  n.a./n.r.    n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0  n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)                2.0      0.091    n.a./n.r.
#  Chloroethane (ethyl chloride)                2.0  n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane                       2.0  n.a./n.r.    n.a./n.r.
#  ...                                          ...        ...          ...
#  Nitrobenzene                                 2.0  n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene                       2.0     0.3691       0.2827
#  Hexachloro-1,3-butadiene                     2.0     0.4469       0.3938
#  Naphthalene                                  2.0     0.4072       0.3023
#  1,2,3-Trichlorobenzene                       2.0     0.5425       0.4175
#
#                                  08-29-CKS-43 08-29-CKS-44 08-29-CKS-42  \
#  Peak
#  Chloromethane (methyl chloride)          0.2    n.a./n.r.    n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)         0.1173       0.0915    n.a./n.r.
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene                0.2095       0.1783       0.1526
#  Hexachloro-1,3-butadiene              0.2465       0.2143       0.1868
#  Naphthalene                           0.2056       0.1636    n.a./n.r.
#  1,2,3-Trichlorobenzene                0.2655       0.2703       0.1696
#
#                                         H-1        S-1        T-1        U-1  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.      0.083     0.0818      0.078
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  ...                                    ...        ...        ...        ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene              0.1153     0.1152        0.1     0.0588
#  Hexachloro-1,3-butadiene            0.1517     0.1125     0.1229     0.1002
#  Naphthalene                         0.1124  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene              0.1449     0.1286     0.1048      0.091
#
#                                         V-1 08-29-CKS-51 08-29-CKS-52  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.       0.1128       0.0816
#  Chloroethane (ethyl chloride)    n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.    n.a./n.r.    n.a./n.r.
#  ...                                    ...          ...          ...
#  Nitrobenzene                     n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene              0.0556    n.a./n.r.    n.a./n.r.
#  Hexachloro-1,3-butadiene             0.078       0.0694    n.a./n.r.
#  Naphthalene                      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.    n.a./n.r.    n.a./n.r.
#
#                                  08-29-CKS-53 08-29-CKS-54 08-29-CKS-55  \
#  Peak
#  Chloromethane (methyl chloride)    n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)      n.a./n.r.       0.0857    n.a./n.r.
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene             n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Hexachloro-1,3-butadiene              0.0501       0.0434       0.0409
#  Naphthalene                        n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene             n.a./n.r.    n.a./n.r.    n.a./n.r.
#
#                                          56
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.
#  Bromomethane (methyl bromide)       0.0584
#  Chloroethane (ethyl chloride)    n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.
#  ...                                    ...
#  Nitrobenzene                     n.a./n.r.
#  1,2,4-Trichlorobenzene           n.a./n.r.
#  Hexachloro-1,3-butadiene         n.a./n.r.
#  Naphthalene                      n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.
#
#  [85 rows x 17 columns],
#                                   Reporting_Limit   DIH2O-V2   DIH2O-R5  \
#  Peak
#  Chloromethane (methyl chloride)              2.0  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)                2.0     0.2593     0.1632
#  Chloroethane (ethyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                       2.0  n.a./n.r.  n.a./n.r.
#  ...                                          ...        ...        ...
#  1,2,4-Trichlorobenzene                       2.0      3.062     0.7504
#  Hexachloro-1,3-butadiene                     2.0     4.0139     0.8645
#  Naphthalene                                  2.0     2.5409     0.4359
#  1,2,3-Trichlorobenzene                       2.0     3.5924     0.7131
#  NaN                                          NaN        NaN        NaN
#
#                                    DIH2O-V3 8-30-23-kellie-1 8-30-23-kellie-2  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.        n.a./n.r.        n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.        n.a./n.r.        n.a./n.r.
#  Bromomethane (methyl bromide)       0.1315           0.1452        n.a./n.r.
#  Chloroethane (ethyl chloride)    n.a./n.r.        n.a./n.r.        n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.        n.a./n.r.        n.a./n.r.
#  ...                                    ...              ...              ...
#  1,2,4-Trichlorobenzene              0.3532            0.186           0.1794
#  Hexachloro-1,3-butadiene            0.3892            0.188           0.1342
#  Naphthalene                         0.2115           0.1071           0.0986
#  1,2,3-Trichlorobenzene              0.2982           0.1596           0.1357
#  NaN                                    NaN              NaN              NaN
#
#                                  8-30-23-kellie-3 8-30-23-kellie-4  \
#  Peak
#  Chloromethane (methyl chloride)        n.a./n.r.        n.a./n.r.
#  Chloroethene (vinyl chloride)          n.a./n.r.        n.a./n.r.
#  Bromomethane (methyl bromide)          n.a./n.r.           0.1335
#  Chloroethane (ethyl chloride)          n.a./n.r.        n.a./n.r.
#  Trichlorofluoromethane                 n.a./n.r.        n.a./n.r.
#  ...                                          ...              ...
#  1,2,4-Trichlorobenzene                    0.1296           0.1381
#  Hexachloro-1,3-butadiene                  0.1039             0.11
#  Naphthalene                               0.0689           0.0802
#  1,2,3-Trichlorobenzene                    0.1039           0.1171
#  NaN                                          NaN              NaN
#
#                                  8-30-23-kellie-6 09-01-CKS-63  ...  \
#  Peak                                                           ...
#  Chloromethane (methyl chloride)        n.a./n.r.    n.a./n.r.  ...
#  Chloroethene (vinyl chloride)          n.a./n.r.    n.a./n.r.  ...
#  Bromomethane (methyl bromide)             0.0887       0.1231  ...
#  Chloroethane (ethyl chloride)          n.a./n.r.    n.a./n.r.  ...
#  Trichlorofluoromethane                 n.a./n.r.    n.a./n.r.  ...
#  ...                                          ...          ...  ...
#  1,2,4-Trichlorobenzene                    0.0886       0.0789  ...
#  Hexachloro-1,3-butadiene                  0.0645       0.0516  ...
#  Naphthalene                            n.a./n.r.        0.046  ...
#  1,2,3-Trichlorobenzene                    0.0683       0.0674  ...
#  NaN                                          NaN          NaN  ...
#
#                                  9-1-23-Kellie-2 9-1-23-Kellie-3  9-8-KDP-1  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)            0.1057          0.0955  n.a./n.r.
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.  n.a./n.r.
#  ...                                         ...             ...        ...
#  1,2,4-Trichlorobenzene                   0.0287          0.0473     0.0405
#  Hexachloro-1,3-butadiene                  0.036       n.a./n.r.  n.a./n.r.
#  Naphthalene                           n.a./n.r.       n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene                   0.0252          0.0297     0.0309
#  NaN                                         NaN             NaN        NaN
#
#                                   9-8-KDP-2  9-8-KDP-3  9-8-KDP-4 09-11-KDP-1  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.     0.0818     0.0768   n.a./n.r.
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  ...                                    ...        ...        ...         ...
#  1,2,4-Trichlorobenzene              0.0366     0.0429     0.0321   n.a./n.r.
#  Hexachloro-1,3-butadiene         n.a./n.r.  n.a./n.r.      0.021      0.0154
#  Naphthalene                         0.0289  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene              0.0341     0.0291  n.a./n.r.   n.a./n.r.
#  NaN                                    NaN        NaN        NaN         NaN
#
#                                  09-11-KDP-2 09-11-KDP-3   DIH2O-V4
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.      0.0734     0.0915
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.  n.a./n.r.
#  ...                                     ...         ...        ...
#  1,2,4-Trichlorobenzene            n.a./n.r.      0.0243     0.3205
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.     0.2874
#  Naphthalene                       n.a./n.r.   n.a./n.r.     0.2846
#  1,2,3-Trichlorobenzene            n.a./n.r.       0.023     0.3545
#  NaN                                     NaN         NaN        NaN
#
#  [86 rows x 23 columns],
#                                   Reporting_Limit   DIH2O-V3   DIH2O-V4  \
#  Peak
#  Chloromethane (methyl chloride)              2.0  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)                2.0     0.1983     0.1633
#  Chloroethane (ethyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                       2.0  n.a./n.r.  n.a./n.r.
#  ...                                          ...        ...        ...
#  Nitrobenzene                                 2.0  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene                       2.0     1.7412     0.5785
#  Hexachloro-1,3-butadiene                     2.0     2.2775     0.6351
#  Naphthalene                                  2.0     1.3128     0.3516
#  1,2,3-Trichlorobenzene                       2.0     1.6759     0.4724
#
#                                    DIH2O-V5 9-12-CKS-1 9-12-CKS-2 9-12-CKS-3   \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)       0.1435  n.a./n.r.     0.1394      0.1035
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  ...                                    ...        ...        ...         ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.  n.a./n.r.   n.a./n.r.
#  1,2,4-Trichlorobenzene               0.311     0.2126     0.1675      0.1018
#  Hexachloro-1,3-butadiene            0.3569      0.214     0.1703      0.0873
#  Naphthalene                         0.1799     0.1194     0.0948      0.0553
#  1,2,3-Trichlorobenzene              0.2661     0.1744     0.1336      0.0858
#
#                                  9-12-CKS-4 09-12-KDP-1 09-12-KDP-2  ...  \
#  Peak                                                                ...
#  Chloromethane (methyl chloride)  n.a./n.r.   n.a./n.r.   n.a./n.r.  ...
#  Chloroethene (vinyl chloride)    n.a./n.r.   n.a./n.r.   n.a./n.r.  ...
#  Bromomethane (methyl bromide)    n.a./n.r.   n.a./n.r.      0.0797  ...
#  Chloroethane (ethyl chloride)    n.a./n.r.   n.a./n.r.   n.a./n.r.  ...
#  Trichlorofluoromethane           n.a./n.r.   n.a./n.r.   n.a./n.r.  ...
#  ...                                    ...         ...         ...  ...
#  Nitrobenzene                     n.a./n.r.   n.a./n.r.   n.a./n.r.  ...
#  1,2,4-Trichlorobenzene              0.0885      0.0677      0.0552  ...
#  Hexachloro-1,3-butadiene            0.0857      0.0639      0.0582  ...
#  Naphthalene                          0.042      0.0407   n.a./n.r.  ...
#  1,2,3-Trichlorobenzene              0.0693      0.0545      0.0474  ...
#
#                                  9-14-CKS-4 9-14-Cks-5 09-14-Cks-6 09-14-JJ-1  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)       0.0989  n.a./n.r.      0.1137     0.0926
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  ...                                    ...        ...         ...        ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene              0.0374     0.0225      0.0272     0.0347
#  Hexachloro-1,3-butadiene         n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  Naphthalene                      n.a./n.r.  n.a./n.r.   n.a./n.r.  n.a./n.r.
#  1,2,3-Trichlorobenzene           n.a./n.r.  n.a./n.r.   n.a./n.r.     0.0244
#
#                                  09-14-JJ-2 9-14-CKS-8 231003-Holmes  \
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.     n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.     n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.     0.0916     n.a./n.r.
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.     n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.     n.a./n.r.
#  ...                                    ...        ...           ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.     n.a./n.r.
#  1,2,4-Trichlorobenzene           n.a./n.r.  n.a./n.r.          0.02
#  Hexachloro-1,3-butadiene         n.a./n.r.  n.a./n.r.     n.a./n.r.
#  Naphthalene                      n.a./n.r.  n.a./n.r.     n.a./n.r.
#  1,2,3-Trichlorobenzene              0.0225  n.a./n.r.     n.a./n.r.
#
#                                  09-14-JJ-3 09-14-JJ-4   DIH2O-V6
#  Peak
#  Chloromethane (methyl chloride)  n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)    n.a./n.r.     0.0673     0.0674
#  Chloroethane (ethyl chloride)    n.a./n.r.  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane           n.a./n.r.  n.a./n.r.  n.a./n.r.
#  ...                                    ...        ...        ...
#  Nitrobenzene                     n.a./n.r.  n.a./n.r.  n.a./n.r.
#  1,2,4-Trichlorobenzene              0.0187     0.0199     0.2245
#  Hexachloro-1,3-butadiene         n.a./n.r.     0.0163     0.2599
#  Naphthalene                      n.a./n.r.  n.a./n.r.     0.2074
#  1,2,3-Trichlorobenzene           n.a./n.r.     0.0163     0.2488
#
#  [85 rows x 24 columns],
#                                   Reporting_Limit     H2O-V3     H2O-V4  \
#  Peak
#  Chloromethane (methyl chloride)              2.0  n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)                2.0  n.a./n.r.  n.a./n.r.
#  Chloroethane (ethyl chloride)                2.0  n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane                       2.0  n.a./n.r.  n.a./n.r.
#  ...                                          ...        ...        ...
#  1,2,4-Trichlorobenzene                       2.0     0.1889     0.0711
#  Hexachloro-1,3-butadiene                     2.0     0.1984     0.0665
#  Naphthalene                                  2.0      0.135     0.0464
#  1,2,3-Trichlorobenzene                       2.0     0.1754     0.0701
#  NaN                                          NaN        NaN        NaN
#
#                                  09-14-KDP-1 09-14-KDP-2 09-14-KDP-3  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.   n.a./n.r.      0.0747
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene               0.0292      0.0301      0.0262
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                          0.0153   n.a./n.r.       0.019
#  1,2,3-Trichlorobenzene               0.0241      0.0198   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-14-KDP-4 09-14-KDP-5 09-18-KDP-1  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.   n.a./n.r.      0.0696
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene               0.0224   n.a./n.r.   n.a./n.r.
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                          0.0231   n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-18-KDP-2  ... 201004-Holmes 09-19-KDP-4  \
#  Peak                                         ...
#  Chloromethane (methyl chloride)   n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)        0.0531  ...        0.0714      0.0601
#  Chloroethane (ethyl chloride)     n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  ...                                     ...  ...           ...         ...
#  1,2,4-Trichlorobenzene            n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  Hexachloro-1,3-butadiene          n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  Naphthalene                       n.a./n.r.  ...        0.0073   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.  ...     n.a./n.r.   n.a./n.r.
#  NaN                                     NaN  ...           NaN         NaN
#
#                                  09-19-KDP-5 09-22-KDP-8 09-22-KDP-7  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.   n.a./n.r.      0.0503
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                       n.a./n.r.   n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-22-KDP-6 09-22-KDP-5 09-22-KDP-4  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)        0.0787      0.0638   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                       n.a./n.r.   n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-22-KDP-3     H2O-V5
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.  n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.  n.a./n.r.
#  Bromomethane (methyl bromide)        0.0936  n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.  n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.  n.a./n.r.
#  ...                                     ...        ...
#  1,2,4-Trichlorobenzene            n.a./n.r.     0.2115
#  Hexachloro-1,3-butadiene          n.a./n.r.     0.2017
#  Naphthalene                       n.a./n.r.     0.1917
#  1,2,3-Trichlorobenzene            n.a./n.r.     0.2149
#  NaN                                     NaN        NaN
#
#  [86 rows x 24 columns],
#                                   Reporting_Limit     H2O-V1 09-22-KDP-9  \
#  Peak
#  Chloromethane (methyl chloride)              2.0  n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0  n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)                2.0  n.a./n.r.   n.a./n.r.
#  Chloroethane (ethyl chloride)                2.0  n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane                       2.0  n.a./n.r.   n.a./n.r.
#  ...                                          ...        ...         ...
#  1,2,4-Trichlorobenzene                       2.0      0.189      0.1413
#  Hexachloro-1,3-butadiene                     2.0       0.13      0.0744
#  Naphthalene                                  2.0     0.1138      0.0777
#  1,2,3-Trichlorobenzene                       2.0     0.1461      0.1106
#  NaN                                          NaN        NaN         NaN
#
#                                  09-22-KDP-10 09-25-KDP-1 09-25-KDP-2  \
#  Peak
#  Chloromethane (methyl chloride)    n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)         0.0607      0.0729   n.a./n.r.
#  Chloroethane (ethyl chloride)      n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                      ...         ...         ...
#  1,2,4-Trichlorobenzene                0.0937      0.0536      0.0427
#  Hexachloro-1,3-butadiene              0.0426      0.0353      0.0223
#  Naphthalene                           0.0558      0.0395      0.0368
#  1,2,3-Trichlorobenzene                0.0674      0.0486      0.0373
#  NaN                                      NaN         NaN         NaN
#
#                                  09-25-KDP-3 09-25-KDP-4 09-25-KDP-5  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)        0.0688   n.a./n.r.   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene               0.0524      0.0593      0.0418
#  Hexachloro-1,3-butadiene             0.0281      0.0213   n.a./n.r.
#  Naphthalene                          0.0418      0.0314      0.0267
#  1,2,3-Trichlorobenzene               0.0514      0.0402   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-25-KDP-6  ... 09-27-KDP-2 09-27-KDP-3  \
#  Peak                                         ...
#  Chloromethane (methyl chloride)   n.a./n.r.  ...   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.  ...   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)        0.0636  ...      0.0542   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.  ...   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.  ...   n.a./n.r.   n.a./n.r.
#  ...                                     ...  ...         ...         ...
#  1,2,4-Trichlorobenzene               0.0351  ...   n.a./n.r.      0.0109
#  Hexachloro-1,3-butadiene             0.0146  ...      0.0056   n.a./n.r.
#  Naphthalene                          0.0235  ...   n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.  ...   n.a./n.r.   n.a./n.r.
#  NaN                                     NaN  ...         NaN         NaN
#
#                                  09-27-KDP-4 09-27-KDP-5 09-27-KDP-6  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene               0.0106      0.0115       0.013
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                       n.a./n.r.   n.a./n.r.   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  NaN                                     NaN         NaN         NaN
#
#                                  09-27-KDP-8 09-27-KDP-7 09-27-KDP-9  \
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...         ...
#  1,2,4-Trichlorobenzene            n.a./n.r.      0.0103      0.0082
#  Hexachloro-1,3-butadiene          n.a./n.r.   n.a./n.r.   n.a./n.r.
#  Naphthalene                       n.a./n.r.      0.0118   n.a./n.r.
#  1,2,3-Trichlorobenzene            n.a./n.r.   n.a./n.r.      0.0066
#  NaN                                     NaN         NaN         NaN
#
#                                  09-27-KDP-10 H2O-HCl-OmniTrace
#  Peak
#  Chloromethane (methyl chloride)    n.a./n.r.         n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.         n.a./n.r.
#  Bromomethane (methyl bromide)      n.a./n.r.            0.0879
#  Chloroethane (ethyl chloride)      n.a./n.r.         n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.         n.a./n.r.
#  ...                                      ...               ...
#  1,2,4-Trichlorobenzene             n.a./n.r.            0.0307
#  Hexachloro-1,3-butadiene           n.a./n.r.            0.0185
#  Naphthalene                           0.0113         n.a./n.r.
#  1,2,3-Trichlorobenzene             n.a./n.r.         n.a./n.r.
#  NaN                                      NaN               NaN
#
#  [86 rows x 40 columns],
#                                   Reporting_Limit 09-22-KDP-2 09-22-KDP-1  \
#  Peak
#  Chloromethane (methyl chloride)              2.0   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)                2.0   n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)                2.0      0.0685      0.0742
#  Chloroethane (ethyl chloride)                2.0   n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane                       2.0   n.a./n.r.   n.a./n.r.
#  ...                                          ...         ...         ...
#  Nitrobenzene                                 2.0   n.a./n.r.   n.a./n.r.
#  1,2,4-Trichlorobenzene                       2.0      0.1142      0.0755
#  Hexachloro-1,3-butadiene                     2.0      0.0829      0.0572
#  Naphthalene                                  2.0      0.0641      0.0472
#  1,2,3-Trichlorobenzene                       2.0      0.0908      0.0599
#
#                                  10-02-KDP-1 10-02-KDP-2
#  Peak
#  Chloromethane (methyl chloride)   n.a./n.r.   n.a./n.r.
#  Chloroethene (vinyl chloride)     n.a./n.r.   n.a./n.r.
#  Bromomethane (methyl bromide)        0.0612   n.a./n.r.
#  Chloroethane (ethyl chloride)     n.a./n.r.   n.a./n.r.
#  Trichlorofluoromethane            n.a./n.r.   n.a./n.r.
#  ...                                     ...         ...
#  Nitrobenzene                      n.a./n.r.   n.a./n.r.
#  1,2,4-Trichlorobenzene               0.0598       0.055
#  Hexachloro-1,3-butadiene             0.0437      0.0339
#  Naphthalene                          0.0392      0.0332
# ...
#  1,2,3-Trichlorobenzene                0.011      0.0123       0.0089
#
#                                  08-02-KDP-02 08-02-KDP-03 08-01-KDP-04  \
#  Peak
#  Chloromethane (methyl chloride)    n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)         0.1871       0.2124       0.1756
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene                0.0138       0.0128        0.014
#  Hexachloro-1,3-butadiene              0.0037    n.a./n.r.    n.a./n.r.
#  Naphthalene                        n.a./n.r.    n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene             n.a./n.r.    n.a./n.r.    n.a./n.r.
#
#                                  08-02-KDP-05 08-02-KDP-06
#  Peak
#  Chloromethane (methyl chloride)    n.a./n.r.       0.2837
#  Chloroethene (vinyl chloride)      n.a./n.r.    n.a./n.r.
#  Bromomethane (methyl bromide)         0.1514       0.2268
#  Chloroethane (ethyl chloride)      n.a./n.r.    n.a./n.r.
#  Trichlorofluoromethane             n.a./n.r.    n.a./n.r.
#  ...                                      ...          ...
#  Nitrobenzene                       n.a./n.r.    n.a./n.r.
#  1,2,4-Trichlorobenzene                0.0104       0.0097
#  Hexachloro-1,3-butadiene           n.a./n.r.       0.0041
#  Naphthalene                        n.a./n.r.    n.a./n.r.
#  1,2,3-Trichlorobenzene                0.0079       0.0076
#
#  [85 rows x 14 columns],
#                                  Reporting_Limit 8-29-24-cks1FBno  \
#  Peak
#  Chloromethane (methyl chloride)               1        n.a./n.r.
#  Chloroethene (vinyl chloride)                 1        n.a./n.r.
#  Bromomethane (methyl bromide)                 1           0.2043
#  Chloroethane (ethyl chloride)                 1        n.a./n.r.
#  Trichlorofluoromethane                        1        n.a./n.r.
#  ...                                         ...              ...
#  Nitrobenzene                                  5        n.a./n.r.
#  1,2,4-Trichlorobenzene                        1           0.0473
#  Hexachloro-1,3-butadiene                      1           0.0357
#  Naphthalene                                 0.5           0.0336
#  1,2,3-Trichlorobenzene                        1           0.0407
#
#                                  8-29-24-Cks-2FBHCL 8-29-24-Cks-3CBno  \
#  Peak
#  Chloromethane (methyl chloride)             0.6834            0.7115
#  Chloroethene (vinyl chloride)            n.a./n.r.         n.a./n.r.
#  Bromomethane (methyl bromide)               0.1947            0.2392
#  Chloroethane (ethyl chloride)               0.1097            0.1243
#  Trichlorofluoromethane                   n.a./n.r.         n.a./n.r.
#  ...                                            ...               ...
#  Nitrobenzene                             n.a./n.r.         n.a./n.r.
#  1,2,4-Trichlorobenzene                      0.0384            0.0325
#  Hexachloro-1,3-butadiene                    0.0314            0.0283
#  Naphthalene                                 0.0241            0.0211
#  1,2,3-Trichlorobenzene                      0.0318            0.0246
#
#                                  8-29-24-cks-4CBHCL 8-29-24-Cks-5  \
#  Peak
#  Chloromethane (methyl chloride)             1.0623        0.7308
#  Chloroethene (vinyl chloride)            n.a./n.r.     n.a./n.r.
#  Bromomethane (methyl bromide)               0.1989        0.2265
#  Chloroethane (ethyl chloride)               0.1966        0.1307
#  Trichlorofluoromethane                   n.a./n.r.     n.a./n.r.
#  ...                                            ...           ...
#  Nitrobenzene                             n.a./n.r.     n.a./n.r.
#  1,2,4-Trichlorobenzene                      0.0275        0.0218
#  Hexachloro-1,3-butadiene                    0.0128        0.0152
#  Naphthalene                                 0.0164     n.a./n.r.
#  1,2,3-Trichlorobenzene                      0.0186        0.0193
#
#                                  8-29-24-Cks-6 8-29-24-CKS-7 08-30-24-KDP-01  \
#  Peak
#  Chloromethane (methyl chloride)        0.6108        0.7336       n.a./n.r.
#  Chloroethene (vinyl chloride)       n.a./n.r.     n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)          0.1893        0.2018          0.1527
#  Chloroethane (ethyl chloride)          0.0991        0.1343       n.a./n.r.
#  Trichlorofluoromethane              n.a./n.r.     n.a./n.r.       n.a./n.r.
#  ...                                       ...           ...             ...
#  Nitrobenzene                        n.a./n.r.     n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                 0.0216        0.0171           0.016
#  Hexachloro-1,3-butadiene               0.0149     n.a./n.r.          0.0079
#  Naphthalene                         n.a./n.r.        0.0106       n.a./n.r.
#  1,2,3-Trichlorobenzene                 0.0157        0.0114          0.0119
#
#                                  08-30-24-KDP-02  ... 08-30-24-KDP-04  \
#  Peak                                             ...
#  Chloromethane (methyl chloride)       n.a./n.r.  ...            0.29
#  Chloroethene (vinyl chloride)         n.a./n.r.  ...       n.a./n.r.
#  Bromomethane (methyl bromide)            0.2113  ...          0.2134
#  Chloroethane (ethyl chloride)         n.a./n.r.  ...       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.  ...       n.a./n.r.
#  ...                                         ...  ...             ...
#  Nitrobenzene                          n.a./n.r.  ...       n.a./n.r.
#  1,2,4-Trichlorobenzene                    0.017  ...          0.0156
#  Hexachloro-1,3-butadiene                 0.0046  ...          0.0049
#  Naphthalene                           n.a./n.r.  ...       n.a./n.r.
#  1,2,3-Trichlorobenzene                   0.0108  ...          0.0105
#
#                                  08-30-24-KDP-05 08-30-24-KDP-06  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.1437          0.1593
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0144          0.0115
#  Hexachloro-1,3-butadiene              n.a./n.r.          0.0076
#  Naphthalene                           n.a./n.r.       n.a./n.r.
#  1,2,3-Trichlorobenzene                    0.007           0.008
#
#                                  08-30-24-KDP-07 08-30-24-KDP-08  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.2005       n.a./n.r.
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0105          0.0099
#  Hexachloro-1,3-butadiene              n.a./n.r.       n.a./n.r.
#  Naphthalene                           n.a./n.r.          0.0765
#  1,2,3-Trichlorobenzene                   0.0071       n.a./n.r.
#
#                                  08-30-24-KDP-09 08-30-24-KDP-10  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)         n.a./n.r.          0.1878
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                    0.009          0.0086
#  Hexachloro-1,3-butadiene              n.a./n.r.       n.a./n.r.
#  Naphthalene                              0.0093       n.a./n.r.
#  1,2,3-Trichlorobenzene                n.a./n.r.       n.a./n.r.
#
#                                  08-30-24-KDP-11 08-30-24-KDP-13  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)         n.a./n.r.          0.1671
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0089       n.a./n.r.
#  Hexachloro-1,3-butadiene              n.a./n.r.          0.0029
#  Naphthalene                           n.a./n.r.       n.a./n.r.
#  1,2,3-Trichlorobenzene                   0.0055       n.a./n.r.
#
#                                  08-30-24-KDP-12
#  Peak
#  Chloromethane (methyl chloride)          0.5861
#  Chloroethene (vinyl chloride)         n.a./n.r.
#  Bromomethane (methyl bromide)            0.1804
#  Chloroethane (ethyl chloride)         n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.
#  ...                                         ...
#  Nitrobenzene                          n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0335
#  Hexachloro-1,3-butadiene                 0.0281
#  Naphthalene                              0.0252
#  1,2,3-Trichlorobenzene                   0.0287
#
#  [85 rows x 21 columns],
#                                  Reporting_Limit 10-04-24-KDP-01  \
#  Peak
#  Chloromethane (methyl chloride)               1       n.a./n.r.
#  Chloroethene (vinyl chloride)                 1       n.a./n.r.
#  Bromomethane (methyl bromide)                 1          0.1669
#  Chloroethane (ethyl chloride)                 1       n.a./n.r.
#  Trichlorofluoromethane                        1       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                                  5       n.a./n.r.
#  1,2,4-Trichlorobenzene                        1          0.0655
#  Hexachloro-1,3-butadiene                      1          0.0311
#  Naphthalene                                 0.5          0.0542
#  1,2,3-Trichlorobenzene                        1           0.051
#
#                                  10-04-24-KDP-02 10-04-24-KDP-03  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.1407          0.1304
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0551          0.0463
#  Hexachloro-1,3-butadiene                 0.0229          0.0176
#  Naphthalene                           n.a./n.r.          0.0372
#  1,2,3-Trichlorobenzene                   0.0432       n.a./n.r.
#
#                                  10-04-24-KDP-04 10-04-24-KDP-05  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.1736          0.1144
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                    0.037          0.0285
#  Hexachloro-1,3-butadiene              n.a./n.r.          0.0113
#  Naphthalene                           n.a./n.r.           0.023
#  1,2,3-Trichlorobenzene                   0.0339           0.025
#
#                                  10-04-24-KDP-06 10-04-24-KDP-07  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.1298          0.1284
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0264           0.024
#  Hexachloro-1,3-butadiene              n.a./n.r.       n.a./n.r.
#  Naphthalene                           n.a./n.r.          0.0188
#  1,2,3-Trichlorobenzene                   0.0244          0.0192
#
#                                  10-04-24-KDP-08 10-04-24-KDP-09  \
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.       n.a./n.r.
#  Bromomethane (methyl bromide)            0.1408          0.1014
#  Chloroethane (ethyl chloride)         n.a./n.r.       n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.       n.a./n.r.
#  ...                                         ...             ...
#  Nitrobenzene                          n.a./n.r.       n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0234          0.0218
#  Hexachloro-1,3-butadiene              n.a./n.r.       n.a./n.r.
#  Naphthalene                           n.a./n.r.       n.a./n.r.
#  1,2,3-Trichlorobenzene                   0.0165       n.a./n.r.
#
#                                  10-04-24-KDP-10
#  Peak
#  Chloromethane (methyl chloride)       n.a./n.r.
#  Chloroethene (vinyl chloride)         n.a./n.r.
#  Bromomethane (methyl bromide)            0.1074
#  Chloroethane (ethyl chloride)         n.a./n.r.
#  Trichlorofluoromethane                n.a./n.r.
#  ...                                         ...
#  Nitrobenzene                          n.a./n.r.
#  1,2,4-Trichlorobenzene                   0.0144
#  Hexachloro-1,3-butadiene                 0.0076
#  Naphthalene                           n.a./n.r.
#  1,2,3-Trichlorobenzene                   0.0137
#
#  [85 rows x 11 columns]]

# %%
# ----------------------------------------------------------------------------------------------------#
# - Calc detects -
# ----------------------------------------------------------------------------------------------------#

def compare_samples_to_limit(df):
    # Identify the reporting limit column
    limit_col = [col for col in df.columns if 'Reporting_Limit' in col][0]
    
    # Identify the sample columns (all columns except the reporting limit)
    sample_cols = [col for col in df.columns if col != limit_col]
    
    # Compare and set sample values
    for sample_col in sample_cols:
        df[sample_col] = df.apply(lambda row: np.nan if row[sample_col] < row[limit_col] else row[sample_col], axis=1)
    
    return df

# Process each DataFrame
for i, df in enumerate(dataframes):
    df.replace(['n.a.', 'n.a./n.r.'], np.nan, inplace=True)
    # Convert all values to numeric (float), coercing errors to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    dataframes[i] = compare_samples_to_limit(df) 
df
#ALL VALUES LESS THAN REPORTING LIMIT IS SET TO NAN#
# Out:
#                                  Reporting_Limit  10-04-24-KDP-01  \
# Peak
# Chloromethane (methyl chloride)              1.0              NaN
# Chloroethene (vinyl chloride)                1.0              NaN
# Bromomethane (methyl bromide)                1.0              NaN
# Chloroethane (ethyl chloride)                1.0              NaN
# Trichlorofluoromethane                       1.0              NaN
# ...                                          ...              ...
# Nitrobenzene                                 5.0              NaN
# 1,2,4-Trichlorobenzene                       1.0              NaN
# Hexachloro-1,3-butadiene                     1.0              NaN
# Naphthalene                                  0.5              NaN
# 1,2,3-Trichlorobenzene                       1.0              NaN
#
#                                  10-04-24-KDP-02  10-04-24-KDP-03  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
# ...                                          ...              ...
# Nitrobenzene                                 NaN              NaN
# 1,2,4-Trichlorobenzene                       NaN              NaN
# Hexachloro-1,3-butadiene                     NaN              NaN
# Naphthalene                                  NaN              NaN
# 1,2,3-Trichlorobenzene                       NaN              NaN
#
#                                  10-04-24-KDP-04  10-04-24-KDP-05  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
# ...                                          ...              ...
# Nitrobenzene                                 NaN              NaN
# 1,2,4-Trichlorobenzene                       NaN              NaN
# Hexachloro-1,3-butadiene                     NaN              NaN
# Naphthalene                                  NaN              NaN
# 1,2,3-Trichlorobenzene                       NaN              NaN
#
#                                  10-04-24-KDP-06  10-04-24-KDP-07  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
# ...                                          ...              ...
# Nitrobenzene                                 NaN              NaN
# 1,2,4-Trichlorobenzene                       NaN              NaN
# Hexachloro-1,3-butadiene                     NaN              NaN
# Naphthalene                                  NaN              NaN
# 1,2,3-Trichlorobenzene                       NaN              NaN
#
#                                  10-04-24-KDP-08  10-04-24-KDP-09  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
# ...                                          ...              ...
# Nitrobenzene                                 NaN              NaN
# 1,2,4-Trichlorobenzene                       NaN              NaN
# Hexachloro-1,3-butadiene                     NaN              NaN
# Naphthalene                                  NaN              NaN
# 1,2,3-Trichlorobenzene                       NaN              NaN
#
#                                  10-04-24-KDP-10
# Peak
# Chloromethane (methyl chloride)              NaN
# Chloroethene (vinyl chloride)                NaN
# Bromomethane (methyl bromide)                NaN
# Chloroethane (ethyl chloride)                NaN
# Trichlorofluoromethane                       NaN
# ...                                          ...
# Nitrobenzene                                 NaN
# 1,2,4-Trichlorobenzene                       NaN
# Hexachloro-1,3-butadiene                     NaN
# Naphthalene                                  NaN
# 1,2,3-Trichlorobenzene                       NaN
#
# [85 rows x 11 columns]

# %% [markdown]
# ### Combine Datasets

# %%
# ----------------------------------------------------------------------------------------------------#
# - Combine both datasets -
# ----------------------------------------------------------------------------------------------------#

# Combine all DataFrames into one using an outer join to align the chemicals
combined_df = pd.concat(dataframes, axis=1, join='outer')

# Display the combined DataFrame
print("Combined DataFrame:")
combined_df.head()
# Out:
# Combined DataFrame:
#                                  Reporting_Limit  HolmesTap  08-16-CKS-1  \
# Peak
# Chloromethane (methyl chloride)              2.0        NaN          NaN
# Chloroethene (vinyl chloride)                2.0        NaN          NaN
# Bromomethane (methyl bromide)                2.0        NaN          NaN
# Chloroethane (ethyl chloride)                2.0        NaN          NaN
# Trichlorofluoromethane                       2.0        NaN          NaN
#
#                                  08-16-CKS-2  08-16-CKS-7  08-16-CKS-8  \
# Peak
# Chloromethane (methyl chloride)          NaN          NaN          NaN
# Chloroethene (vinyl chloride)            NaN          NaN          NaN
# Bromomethane (methyl bromide)            NaN          NaN          NaN
# Chloroethane (ethyl chloride)            NaN          NaN          NaN
# Trichlorofluoromethane                   NaN          NaN          NaN
#
#                                  08-16-CKS-10  08-16-CKS-12  Reporting_Limit  \
# Peak
# Chloromethane (methyl chloride)           NaN           NaN              2.0
# Chloroethene (vinyl chloride)             NaN           NaN              2.0
# Bromomethane (methyl bromide)             NaN           NaN              2.0
# Chloroethane (ethyl chloride)             NaN           NaN              2.0
# Trichlorofluoromethane                    NaN           NaN              2.0
#
#                                  DIH2O-Vial  ...  10-04-24-KDP-01  \
# Peak                                         ...
# Chloromethane (methyl chloride)         NaN  ...              NaN
# Chloroethene (vinyl chloride)           NaN  ...              NaN
# Bromomethane (methyl bromide)           NaN  ...              NaN
# Chloroethane (ethyl chloride)           NaN  ...              NaN
# Trichlorofluoromethane                  NaN  ...              NaN
#
#                                  10-04-24-KDP-02  10-04-24-KDP-03  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
#
#                                  10-04-24-KDP-04  10-04-24-KDP-05  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
#
#                                  10-04-24-KDP-06  10-04-24-KDP-07  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
#
#                                  10-04-24-KDP-08  10-04-24-KDP-09  \
# Peak
# Chloromethane (methyl chloride)              NaN              NaN
# Chloroethene (vinyl chloride)                NaN              NaN
# Bromomethane (methyl bromide)                NaN              NaN
# Chloroethane (ethyl chloride)                NaN              NaN
# Trichlorofluoromethane                       NaN              NaN
#
#                                  10-04-24-KDP-10
# Peak
# Chloromethane (methyl chloride)              NaN
# Chloroethene (vinyl chloride)                NaN
# Bromomethane (methyl bromide)                NaN
# Chloroethane (ethyl chloride)                NaN
# Trichlorofluoromethane                       NaN
#
# [5 rows x 680 columns]

# %%
#Define chemical list

specified_chemicals = ["Chloromethane (methyl chloride)", "Chloroethene (vinyl chloride)", 
    "Bromomethane (methyl bromide)", "Chloroethane (ethyl chloride)",
    "Trichlorofluoromethane", "Diethyl ether", "1,1-Dichloroethene", "Acetone",
    "Iodomethane", "Carbon disulfide", "3-Chloropropene (allyl chloride)",
    "Methylene chloride (DCM)", "trans-1,2-Dichloroethene", "Methyl tert-butyl ether (MTBE)",
    "1,1-Dichloroethane", "2,2-Dichloropropane", "cis-1,2-Dichloroethene", "2-Butanone (MEK)",
    "Methyl acrylate", "Methacrylonitrile", "Bromochloromethane", "Tetrahydrofuran",
    "Trichloromethane (chloroform)", "1,1,1-Trichloroethane", "1-Chlorobutane (butyl chloride)", "Carbon tetrachloride",
    "1,1-Dichloropropene", "Benzene", "1,2-Dichloroethane",
    "Trichloroethene", "1,2-Dichloropropane", "Dibromomethane", "Methyl methacrylate",
    "Bromodichloromethane", "2-Nitropropane", "cis-1,3-Dichloropropene", "4-Methyl-2-pentanone (MIBK)", "Toluene", "trans-1,3-Dichloropropene", "Ethyl methacrylate",
    "1,1,2-Trichloroethane", "Tetrachloroethene", "1,3-Dichloropropane", "2-Hexanone",
    "Dibromochloromethane", "1,2-Dibromoethane (EDB)", "Chlorobenzene",
    "1,1,1,2-Tetrachloroethane", "Ethylbenzene", "m/p-Xylene", "o-Xylene", "Styrene",
    "Bromoform", "Isopropylbenzene (cumene)","Bromobenzene", "1,1,2,2-Tetrachloroethane", "1,2,3-Trichloropropane (TCP)",
    "trans-1,4-Dichloro-2-butene", "n-Propylbenzene", "2-Chlorotoluene", "1,3,5-Trimethylbenzene",
    "4-Chlorotoluene", "tert-Butylbenzene", "Pentachloroethane", "1,2,4-Trimethylbenzene",
    "1-Methylpropylbenzene (sec-butylbenzene)", "1,3-Dichlorobenzene", "4-Isopropyltoluene (p-cymene)", "1,4-Dichlorobenzene", "n-Butylbenzene", "1,2-Dichlorobenzene",
    "Hexachloroethane", "1,2-Dibromo-3-chloropropane (DBCP)", "Nitrobenzene", "1,2,4-Trichlorobenzene",
    "Hexachloro-1,3-butadiene", "Naphthalene", "1,2,3-Trichlorobenzene"
]

# %% [markdown]
# ### Clean combined dataframe

# %%
filtered_combined_df = combined_df.loc[specified_chemicals]

# Transpose the filtered dataframe
transposed_df = filtered_combined_df.T

# Reset the index to turn columns into rows
transposed_df.reset_index(inplace=True)
transposed_df.rename(columns={'index': 'Sample ID'}, inplace=True)


merged_df = pd.merge(tapwaterdf, transposed_df, on='Sample ID', how='inner')
merged_df
# Out:
#            Sample ID SampleType   DateTime Taken Post Results    Public X  \
# 0        08-16-CKS-2  Tap Water   8/16/2023 9:30          NaN -156.311886
# 1        08-16-CKS-3  Tap Water  8/16/2023 10:52          NaN -156.309926
# 2        08-16-CKS-4  Tap Water  8/16/2023 11:11          NaN -156.307487
# 3        08-16-CKS-6  Tap Water  8/16/2023 12:00          NaN -156.310399
# 4        08-16-CKS-7  Tap Water  8/16/2023 12:22          NaN -156.309802
# ..               ...        ...              ...          ...         ...
# 358  10-04-24-KDP-02  Tap Water  10/4/2024 14:46          NaN -156.314311
# 359  10-04-24-KDP-04  Tap Water  10/4/2024 14:52          NaN -156.321881
# 360  10-04-24-KDP-06  Tap Water  10/4/2024 15:10          NaN -156.214123
# 361  10-04-24-KDP-07  Tap Water  10/4/2024 15:13          NaN -156.379997
# 362  10-04-24-KDP-09  Tap Water  10/4/2024 15:21          NaN -156.496896
#
#       Public Y  Chloromethane (methyl chloride)  \
# 0    20.778782                              NaN
# 1    20.779907                              NaN
# 2    20.775916                              NaN
# 3    20.774751                              NaN
# 4    20.773082                              NaN
# ..         ...                              ...
# 358  20.877163                              NaN
# 359  20.918979                              NaN
# 360  20.895677                              NaN
# 361  20.915937                              NaN
# 362  20.923693                              NaN
#
#      Chloroethene (vinyl chloride)  Bromomethane (methyl bromide)  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ..                             ...                            ...
# 358                            NaN                            NaN
# 359                            NaN                            NaN
# 360                            NaN                            NaN
# 361                            NaN                            NaN
# 362                            NaN                            NaN
#
#      Chloroethane (ethyl chloride)  ...  1,4-Dichlorobenzene  n-Butylbenzene  \
# 0                              NaN  ...                  NaN             NaN
# 1                              NaN  ...                  NaN             NaN
# 2                              NaN  ...                  NaN             NaN
# 3                              NaN  ...                  NaN             NaN
# 4                              NaN  ...                  NaN             NaN
# ..                             ...  ...                  ...             ...
# 358                            NaN  ...                  NaN             NaN
# 359                            NaN  ...                  NaN             NaN
# 360                            NaN  ...                  NaN             NaN
# 361                            NaN  ...                  NaN             NaN
# 362                            NaN  ...                  NaN             NaN
#
#      1,2-Dichlorobenzene  Hexachloroethane  \
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
# ..                   ...               ...
# 358                  NaN               NaN
# 359                  NaN               NaN
# 360                  NaN               NaN
# 361                  NaN               NaN
# 362                  NaN               NaN
#
#      1,2-Dibromo-3-chloropropane (DBCP)  Nitrobenzene  1,2,4-Trichlorobenzene  \
# 0                                   NaN           NaN                     NaN
# 1                                   NaN           NaN                     NaN
# 2                                   NaN           NaN                     NaN
# 3                                   NaN           NaN                     NaN
# 4                                   NaN           NaN                     NaN
# ..                                  ...           ...                     ...
# 358                                 NaN           NaN                     NaN
# 359                                 NaN           NaN                     NaN
# 360                                 NaN           NaN                     NaN
# 361                                 NaN           NaN                     NaN
# 362                                 NaN           NaN                     NaN
#
#      Hexachloro-1,3-butadiene  Naphthalene  1,2,3-Trichlorobenzene
# 0                         NaN          NaN                     NaN
# 1                         NaN          NaN                     NaN
# 2                         NaN          NaN                     NaN
# 3                         NaN          NaN                     NaN
# 4                         NaN          NaN                     NaN
# ..                        ...          ...                     ...
# 358                       NaN          NaN                     NaN
# 359                       NaN          NaN                     NaN
# 360                       NaN          NaN                     NaN
# 361                       NaN          NaN                     NaN
# 362                       NaN          NaN                     NaN
#
# [363 rows x 84 columns]

# %% [markdown]
# ### Calculate Total Trihalomethanes

# %%
def TTHM_Calculator(row):
    TTHM_List = ['Bromodichloromethane', 'Bromoform', 'Dibromochloromethane', 'Trichloromethane (chloroform)']
    empty_List = []
    
    for chemical in TTHM_List:
        value = row.get(chemical, np.nan)
        empty_List.append(value)
    
    TTHM = np.nansum(empty_List)  # Sum the list using nansum to treat NaNs as 0s
    return TTHM
merged_df['Total Trihalomethanes'] = merged_df.apply(TTHM_Calculator, axis=1)

# %% [markdown]
# ### Visualize detects

# %%
non_chemical_columns = ['Sample ID', 'SampleType', 'DateTime Taken', 'Public X', 'Public Y', 'Post Results']
chemical_columns = [col for col in merged_df.columns if col not in non_chemical_columns]
detect_counts = merged_df[chemical_columns].notna().sum()

# Total number of samples is the number of rows in merged_df
total_samples = len(merged_df)

# Create a DataFrame for plotting
detects_df = pd.DataFrame({
    'Chemical': detect_counts.index,
    'Number of Detects': detect_counts.values
}).sort_values(by='Number of Detects', ascending=False)
print(detects_df)

fig, ax = plt.subplots(figsize=(16, 6))  # Increase width to allow more spacing for labels

# Plot the bar chart
plt.bar('Chemical', 'Number of Detects', data=detects_df, color='brown')

# Rotate the x-axis labels and adjust their alignment
plt.xticks(rotation=45, ha='right', fontsize=8)

# Add more space between the x-ticks by reducing the number of ticks shown

# Title and labels
plt.xlabel("Chemicals")
plt.ylabel("Number of Detects")
plt.title(f'Tap Water Chemical Detects in Maui (N = {total_samples})')

# Adjust the layout to ensure everything fits without overlapping
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#                          Chemical  Number of Detects
# 78          Total Trihalomethanes                363
# 22  Trichloromethane (chloroform)                333
# 7                         Acetone                331
# 33           Bromodichloromethane                241
# 44           Dibromochloromethane                199
# ..                            ...                ...
# 1   Chloroethene (vinyl chloride)                  0
# 40          1,1,2-Trichloroethane                  0
# 41              Tetrachloroethene                  0
# 42            1,3-Dichloropropane                  0
# 39             Ethyl methacrylate                  0
#
# [79 rows x 2 columns]

# %% [markdown]
# ### Save files are .csv for further processing

# %%
merged_df.to_csv('All_Samples.csv')
